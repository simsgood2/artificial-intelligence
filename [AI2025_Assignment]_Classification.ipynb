# %% [markdown]
# <a href="https://colab.research.google.com/github/simsgood2/artificial-intelligence/blob/main/%5BAI2025_Assignment%5D_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignments
#
# The assignment of using the chemical composition data of wine to freely train your own classification model among several classifications to identify the type of wine and to check the accuracy of the model.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##Data load and Preprocessing

# %%
from sklearn.datasets import load_wine

wine = load_wine()

# %% [markdown]
# ##Inspecting Data and Splitting Train_set, Test_set
#
# * test_size = 0.3
# * Check how the data is organized through print(wine['DESCR'])

# %%
# Check the Dataset Descriptions
print(wine['DESCR'])

# %%
print(wine.feature_names)
print(wine.target_names)

# %% [markdown]
# ### Please define X and Y to predict `class` through `wine_df`.

# %%
wine_df = pd.DataFrame(wine['data'], columns=wine.feature_names)
wine_df['class'] = wine.target

# Setting X, Y
X = wine_df.drop('class', axis=1)
Y = wine_df['class']

# %%
print(X.head())

# %%
print(Y.head())
print(Y.tail())

# %%
################### Freely Preprocess (Scaling MUST be done after splitting train/test!) ######################

# %% [markdown]
# ### Split train and test data through `train_test_split`.
# - test_size = 0.3, random_state = 0

# %%
from sklearn.model_selection import train_test_split

# Splitting Train/Test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
###### Freely Preprocessing 2 : Scaling ( After splitting; Data Leakage) #######
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# X_train 데이터로 스케일러를 학습(fit)시키고 변환(transform)
X_train = scaler.fit_transform(X_train)

# X_train 데이터는 학습된 스케일러로 변환(transform)만 수행
X_test = scaler.transform(X_test)

# %% [markdown]
# ##Build Models Using Various Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier  # 1. RandomForest 임포트
# Generate Model
# model = DecisionTreeClassifier(random_state=0)
model = RandomForestClassifier(random_state=0)   # 2. 모델을 RandomForest로 변경

# Fitting
model.fit(X_train, Y_train)

# Get predict value by predicting with test data
Y_predict = model.predict(X_test)

# %% [markdown]
# ##Check the fitted model's performance

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_predict))

# %% [markdown]
# ### Print the Accuracy.

# %%
# model accuarcy
accuracy = model.score(X_test, Y_test)
print("Accuracy: {0:.3f}".format(accuracy))

# %% [markdown]
# ## Grading
#
# - Accuracy >= 95 : **50 pt(Perfect)**
# - Accuracy >= 93, < 95 : **45 pt**
# - Accuracy >= 90, < 93 : **40 pt**
# - Accuracy < 90 : **35 pt**
